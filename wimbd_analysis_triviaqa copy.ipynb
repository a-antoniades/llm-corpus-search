# %%
import os
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

from src.wimbd_ import BasePaths as PATHS, Colors
from src.wimbd_ import DataConfigs as CONFIG
from src.wimbd_ import post_filter, filter_percentile, load_results
from src.wimbd_ import ProcessTriviaQA as ptqa
from src.utils import remove_nested_lists, softmax
from src.analysis import AnalyzeNgrams as an

from datetime import datetime
pd.set_option('display.max_columns', None)

# Generate a timestamp
timestamp = datetime.now().strftime("%Y-%m-%d-%H:%M")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /local/home/antonis/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /local/home/antonis/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [dynet] random seed: 1234
# [dynet] allocating memory: 32MB
# [dynet] memory allocation done.

# %%
task_coverage_pth = "./results/n-grams/triviaqa/pile/exp_3/validation-set/n_samples_None_fkeyFalse_rkeyFalse_fstopTrue_onlyalphaFalse/3/common/task-p-coverage.pkl"
task_coverage = pd.read_pickle(task_coverage_pth)

# %%
all_models = ['pythia-12b', 'pythia-6.9b', 'pythia-2.8b', 'pythia-1.4b', 'pythia-410m', 'pythia-160m', 'pythia-70m', 'pythia-31m', 'pythia-14m']
large_models = ['pythia-12b', 'pythia-6.9b', 'pythia-2.8b', 'pythia-1.4b']
small_models = ['pythia-410m', 'pythia-160m', 'pythia-70m', 'pythia-31m', 'pythia-14m']

N_GRAMS = 5
ALIGN_THRESH = 0.8
# BASE_DIR = f"./results/n-grams/trivia_qa/pile/exp_3/test-set/n_samples_None_fkeyFalse_rkeyFalse_fstopTrue_onlyalphaFalse/"
# BASE_DIR = f"./results/n-grams/triviaqa/pile/exp_3/validation-set/n_samples_None_fkeyFalse_rkeyFalse_fstopTrue_onlyalphaFalse"
# BASE_DIR = f"./results/n-grams/triviaqa/pile/exp_3/validation-set/n_samples_None_fkeyFalse_rkeyFalse_fstopFalse_onlyalphaFalse"
DATASET = "examples_dfs_0-shot_common_pythia_models.pkl" # "examples_dfs_4-shot_common_models.pkl"
TASKS = "triviaqa"
BASE_DIR = PATHS.base_ngram_paths[TASKS]['base_path'][N_GRAMS]
OMMIT_TASKS = False
TASKS_OMMIT = ["formal_logic"]
POST_FILTER = True

# BASE_DIR = PATHS.base_ngram_paths[TASKS]['base_path']
BASE_PATH = os.path.join(BASE_DIR, f"{N_GRAMS}")
METHOD = "0-shot_common"
BASE_PATH_COMMON = os.path.join(BASE_PATH, "common")
BASE_PATH_ALL = os.path.join(BASE_PATH, "all")
# FIG_DIR = os.path.join("/share/edc/home/antonis/LLM-Incidental-Supervision/incidental-supervision/figures", DATASET, timestamp)
# if not os.path.exists(FIG_DIR):
#     os.makedirs(FIG_DIR)

# RESULTS_PATH = os.path.join(BASE_DIR, str(N_GRAMS), 'common', DATASET)
RESULTS_PATH = os.path.join(BASE_DIR, str(N_GRAMS), DATASET)
FIGS_PTH = "./figures/trivia_qa"

print(f"BASE PATH: {BASE_PATH}")

VIEW_COLS = ['Q', 'A', 'question', 'value', 'align_score', 'em', 'answer']
# Out:
# BASE PATH: ./results/n-grams/triviaqa/pile/exp_3/validation-set/n_samples_None_fkeyFalse_rkeyFalse_fstopFalse_onlyalphaFalse/5

# %%
# filter outliers
pickle_file = pd.read_pickle(RESULTS_PATH)
# df = pd.DataFrame(pickle_file).T.sort_values("value", ascending=False)

# filter
# open
examples_models_pth = os.path.join(BASE_PATH, f"examples_dfs_{METHOD}_post-processed.pkl")
if os.path.exists(examples_models_pth):
    with open(examples_models_pth, 'rb') as f:
        examples_models = pickle.load(f)
else:
    examples_models = ptqa.process_model_examples(pickle_file, p=0.99999)
examples_model = examples_models['pythia-12b']
colors = sns.color_palette('hls', len(examples_models))

# %%
# # save
# with open(os.path.join(BASE_PATH, f"examples_dfs_{METHOD}_post-processed.pkl"), 'wb') as f:
#     pickle.dump(examples_models, f)

# %%
examples_models_ = {model: data[data['align_score'] > ALIGN_THRESH] for model, data in examples_models.items()}

# %%
examples_models_['pythia-12b'].head(20)
# Out:
#                                   Q              A    value  \
# 25             in the middle of the           Pear  1837603
# 22          at the beginning of the             45  1815794
# 38            is the square root of             99  1022052
# 37            is the square root of             12  1022052
# 75   President of the United States  Ronald Reagan   615844
# 76       What is the second biggest     Birmingham   603704
# 45                is one of the few      Southwest   573790
# 99            is the square root of            0.5   511026
# 96            is the square root of             13   511026
# 107       the United States and the  Great Britain   400044
# 255              is the name of the      Sylvester   388166
# 203              is the name of the       Passover   388166
# 227              is the name of the           Nova   388166
# 123              is the name of the            Bow   388166
# 157              is the name of the        America   388166
# 174              is the name of the        Horizon   388166
# 236              is the name of the         Claire   388166
# 197              is the name of the           Mead   388166
# 251              is the name of the           Love   388166
# 272              is the name of the       Geoffrey   388166
#
#                                                example      task  \
# 25   {'question': 'Which fruit can go in the middle...  triviaqa
# 22   {'question': 'How many American states were th...  triviaqa
# 38   {'question': 'What whole two-digit number is t...  triviaqa
# 37   {'question': 'What is the square root of 144?'...  triviaqa
# 75   {'question': 'June 5, 2004 saw the death of wh...  triviaqa
# 76   {'question': 'What is the second biggest city ...  triviaqa
# 45   {'question': 'What successful, no-frills airli...  triviaqa
# 99   {'question': 'What is the square root of 0.25?...  triviaqa
# 96   {'question': 'What is the square root of 169?'...  triviaqa
# 107  {'question': 'After the United States and the ...  triviaqa
# 255  {'question': 'What is the name of the cartoon ...  triviaqa
# 203  {'question': 'What is the name of the Jewish s...  triviaqa
# 227  {'question': 'What is the name of the long run...  triviaqa
# 123  {'question': 'What is the name of the device m...  triviaqa
# 157  {'question': 'What is the name of the yacht th...  triviaqa
# 174  {'question': 'Translating from the Greek as "s...  triviaqa
# 236  {'question': 'What is the name of the female a...  triviaqa
# 197  {'question': 'Also known as honey wine, what i...  triviaqa
# 251  {'question': 'What is the name of the perfume ...  triviaqa
# 272  {'question': 'What is the name of the giraffe ...  triviaqa
#
#                                                 pair  \
# 25                      (in the middle of the, Pear)
# 22                     (at the beginning of the, 45)
# 38                       (is the square root of, 99)
# 37                       (is the square root of, 12)
# 75   (President of the United States, Ronald Reagan)
# 76          (What is the second biggest, Birmingham)
# 45                    (is one of the few, Southwest)
# 99                      (is the square root of, 0.5)
# 96                       (is the square root of, 13)
# 107       (the United States and the, Great Britain)
# 255                  (is the name of the, Sylvester)
# 203                   (is the name of the, Passover)
# 227                       (is the name of the, Nova)
# 123                        (is the name of the, Bow)
# 157                    (is the name of the, America)
# 174                    (is the name of the, Horizon)
# 236                     (is the name of the, Claire)
# 197                       (is the name of the, Mead)
# 251                       (is the name of the, Love)
# 272                   (is the name of the, Geoffrey)
#
#                                          example_clean  coverage  \
# 25   Which fruit can go in the middle of the word a...  0.327478
# 22   How many American states were there at the beg...  0.327478
# 38   What whole two-digit number is the square root...  0.327478
# 37                     What is the square root of 144?  0.327478
# 75   June 5, 2004 saw the death of what man, the 40...  0.327478
# 76          What is the second biggest city in the UK?  0.327478
# 45   What successful, no-frills airline is headquar...  0.327478
# 99                    What is the square root of 0.25?  0.327478
# 96                     What is the square root of 169?  0.327478
# 107  After the United States and the Soviet Union, ...  0.327478
# 255  What is the name of the cartoon cat that is al...  0.327478
# 203  What is the name of the Jewish spring festival...  0.327478
# 227  What is the name of the long running science p...  0.327478
# 123  What is the name of the device made of wood an...  0.327478
# 157  What is the name of the yacht that won the Roy...  0.327478
# 174  Translating from the Greek as "separating circ...  0.327478
# 236  What is the name of the female alter-ego of Tu...  0.327478
# 197  Also known as honey wine, what is the name of ...  0.327478
# 251  What is the name of the perfume launched by Br...  0.327478
# 272  What is the name of the giraffe that Toys-r-us...  0.327478
#
#                                                  query      sum  count  \
# 25   Which fruit can go in the middle of the word a...  1841604     12
# 22   How many American states were there at the beg...  1934174      9
# 38   What whole two-digit number is the square root...  1022324      6
# 37                     What is the square root of 144?  1025754      3
# 75   June 5, 2004 saw the death of what man, the 40...   618248     12
# 76          What is the second biggest city in the UK?   607048      5
# 45   What successful, no-frills airline is headquar...   965976     20
# 99                    What is the square root of 0.25?   511237      3
# 96                     What is the square root of 169?   512476      3
# 107  After the United States and the Soviet Union, ...   482952     19
# 255  What is the name of the cartoon cat that is al...   411110     10
# 203  What is the name of the Jewish spring festival...   415222     14
# 227  What is the name of the long running science p...   413400     19
# 123  What is the name of the device made of wood an...   419174     15
# 157  What is the name of the yacht that won the Roy...   418330     26
# 174  Translating from the Greek as "separating circ...   416400     18
# 236  What is the name of the female alter-ego of Tu...   411842     10
# 197  Also known as honey wine, what is the name of ...   416082     22
# 251  What is the name of the perfume launched by Br...   411240     11
# 272  What is the name of the giraffe that Toys-r-us...   410912      9
#
#           id  gold                                           question  \
# 25   11677_0     0  Which fruit can go in the middle of the word a...
# 22    6957_0     0  How many American states were there at the beg...
# 38   11921_0     0  What whole two-digit number is the square root...
# 37    4141_0     0                    What is the square root of 144?
# 75   15100_0     0  June 5, 2004 saw the death of what man, the 40...
# 76    6697_0     0         What is the second biggest city in the UK?
# 45   12688_0     0  What successful, no-frills airline is headquar...
# 99   15400_0     0                   What is the square root of 0.25?
# 96    9974_0     0                    What is the square root of 169?
# 107   4979_0     0  After the United States and the Soviet Union, ...
# 255   4065_0     0  What is the name of the cartoon cat that is al...
# 203   1791_0     0  What is the name of the Jewish spring festival...
# 227    115_0     0  What is the name of the long running science p...
# 123   4623_0     0  What is the name of the device made of wood an...
# 157   6440_0     0  What is the name of the yacht that won the Roy...
# 174   5865_0     0  Translating from the Greek as "separating circ...
# 236  10688_0     0  What is the name of the female alter-ego of Tu...
# 197   9383_0     0  Also known as honey wine, what is the name of ...
# 251   8451_0     0  What is the name of the perfume launched by Br...
# 272    371_0     0  What is the name of the giraffe that Toys-r-us...
#
#     question_id                        question_source  \
# 25       qz_871           https://www.quiz-zone.co.uk/
# 22    odql_9796              http://www.odquiz.org.uk/
# 38      bb_5981          http://www.businessballs.com/
# 37      qb_7961              http://www.quizballs.com/
# 75      qg_1692         https://quizguy.wordpress.com/
# 76      qz_6268           https://www.quiz-zone.co.uk/
# 45      qg_3574         https://quizguy.wordpress.com/
# 99      bb_2025          http://www.businessballs.com/
# 96      qb_3624              http://www.quizballs.com/
# 107     qg_2879         https://quizguy.wordpress.com/
# 255   sfq_22592                      www.sfquiz.org.uk
# 203      qb_650              http://www.quizballs.com/
# 227     qg_3828         https://quizguy.wordpress.com/
# 123     qz_1191           https://www.quiz-zone.co.uk/
# 157     tb_2281  http://triviabug.com/q-and-a-quizzes/
# 174     qg_1045         https://quizguy.wordpress.com/
# 236     qb_6337              http://www.quizballs.com/
# 197     qg_2345         https://quizguy.wordpress.com/
# 251     qb_9851              http://www.quizballs.com/
# 272     qg_4541         https://quizguy.wordpress.com/
#
#                                           entity_pages  \
# 25   {'doc_source': [], 'filename': [], 'title': []...
# 22   {'doc_source': [], 'filename': [], 'title': []...
# 38   {'doc_source': [], 'filename': [], 'title': []...
# 37   {'doc_source': [], 'filename': [], 'title': []...
# 75   {'doc_source': [], 'filename': [], 'title': []...
# 76   {'doc_source': [], 'filename': [], 'title': []...
# 45   {'doc_source': [], 'filename': [], 'title': []...
# 99   {'doc_source': [], 'filename': [], 'title': []...
# 96   {'doc_source': [], 'filename': [], 'title': []...
# 107  {'doc_source': [], 'filename': [], 'title': []...
# 255  {'doc_source': [], 'filename': [], 'title': []...
# 203  {'doc_source': [], 'filename': [], 'title': []...
# 227  {'doc_source': [], 'filename': [], 'title': []...
# 123  {'doc_source': [], 'filename': [], 'title': []...
# 157  {'doc_source': [], 'filename': [], 'title': []...
# 174  {'doc_source': [], 'filename': [], 'title': []...
# 236  {'doc_source': [], 'filename': [], 'title': []...
# 197  {'doc_source': [], 'filename': [], 'title': []...
# 251  {'doc_source': [], 'filename': [], 'title': []...
# 272  {'doc_source': [], 'filename': [], 'title': []...
#
#                                         search_results  \
# 25   {'description': [], 'filename': [], 'rank': []...
# 22   {'description': [], 'filename': [], 'rank': []...
# 38   {'description': [], 'filename': [], 'rank': []...
# 37   {'description': [], 'filename': [], 'rank': []...
# 75   {'description': [], 'filename': [], 'rank': []...
# 76   {'description': [], 'filename': [], 'rank': []...
# 45   {'description': [], 'filename': [], 'rank': []...
# 99   {'description': [], 'filename': [], 'rank': []...
# 96   {'description': [], 'filename': [], 'rank': []...
# 107  {'description': [], 'filename': [], 'rank': []...
# 255  {'description': [], 'filename': [], 'rank': []...
# 203  {'description': [], 'filename': [], 'rank': []...
# 227  {'description': [], 'filename': [], 'rank': []...
# 123  {'description': [], 'filename': [], 'rank': []...
# 157  {'description': [], 'filename': [], 'rank': []...
# 174  {'description': [], 'filename': [], 'rank': []...
# 236  {'description': [], 'filename': [], 'rank': []...
# 197  {'description': [], 'filename': [], 'rank': []...
# 251  {'description': [], 'filename': [], 'rank': []...
# 272  {'description': [], 'filename': [], 'rank': []...
#
#                                                 answer                    lls  \
# 25   {'aliases': ['Pear (fruit)', 'Pear tree', 'Pea...                  Apple
# 22   {'aliases': ['45', 'forty-five'], 'normalized_...                    Ten
# 38   {'aliases': ['99', 'ninety-nine'], 'normalized...                      9
# 37   {'aliases': ['twelve', '12'], 'normalized_alia...                     12
# 75   {'aliases': ['President Regan', 'Ronald Reagan...          Ronald Reagan
# 76   {'aliases': ['County Borough of Birmingham', '...             Birmingham
# 45   {'aliases': ['RedBellyRadio', 'Southwest Airli...     Southwest Airlines
# 99   {'aliases': ['0.5', 'zero point five'], 'norma...                      0
# 96   {'aliases': ['13', 'thirteen'], 'normalized_al...                     13
# 107  {'aliases': ['Great–Britain', 'England, Scotla...     The United Kingdom
# 255  {'aliases': ['Sylvester', 'Sylvester (name)'],...              Sylvester
# 203  {'aliases': ['Peysach', 'Korban Pesah', 'Pessa...               Passover
# 227  {'aliases': ['Novas', 'Nova', 'Nova and Supern...                   NOVA
# 123  {'aliases': ['Bows', 'Bow (disambiguation)', '...                   Viol
# 157  {'aliases': ['The United States of America', '...   Royal Yacht Squadron
# 174  {'aliases': ['Horizon distance', 'The horizon'...            The Tropics
# 236  {'aliases': ['Clair', 'Clair (disambiguation)'...          Grayson Perry
# 197  {'aliases': ['Hydromel', 'Metheglins', 'Pyment...                   Mead
# 251  {'aliases': ['Idealized love', 'Loveliest', 'L...                    JLS
# 272  {'aliases': ['Geoffrey', 'Geoff', 'Geoffrey (d...                Giraffe
#
#                     result  em  align_score
# 25                   Apple   0    78.528419
# 22                     Ten   0    76.193657
# 38                       9   0    83.908638
# 37                      12   1    84.854713
# 75           Ronald Reagan   1    82.827179
# 76              Birmingham   1    83.078804
# 45      Southwest Airlines   1    74.529900
# 99                       0   0    85.025772
# 96                      13   1    84.718674
# 107     The United Kingdom   0    78.852486
# 255              Sylvester   1    76.956177
# 203               Passover   1    77.623993
# 227                   NOVA   1    77.925346
# 123                   Viol   0    77.723495
# 157   Royal Yacht Squadron   0    76.199295
# 174            The Tropics   0    78.320808
# 236          Grayson Perry   0    76.869308
# 197                   Mead   1    76.968941
# 251                    JLS   0    75.922310
# 272                Giraffe   0    76.256897

# %%
# examples_model_small = examples_model.iloc[0:3]
# examples_model_small_filtered, indices_kept = ptqa.calculate_alignment_scores(examples_model_small, 75, 1)

# %%
# display_cols = ['Q', 'A', 'value', 'example']
# pd.set_option('display.max_rows', 1000)
# pd.set_option('display.max_colwidth', 2)  # Set to None to display full content
# examples_model[display_cols].iloc[200:400]

# %%
from src.analysis import AnalyzeNgrams as an

# coverage_path = os.path.join(BASE_PATH_COMMON, "task-coverage.pkl")
# task_cov = an.calculate_average_task_coverage(BASE_PATH_ALL, [TASKS], [N_GRAMS])

# %%
# # Assuming 'value' is the column with values to bin and we want 5 bins between 1 and 10000
# examples_model = an.create_bins(examples_model, 'value', 1, 10000, 4)

# example_samples_model = ptqa.get_random_samples_by_interval(examples_model, 100)

# ptqa.plot_avg_em_by_log_interval(example_samples_model, log_axis=True)
# ptqa.plot_avg_em_by_log_interval(examples_model, log_axis=True)
# # plot_avg_em_by_log_interval(example_samples_model, log_axis=False)

# %%
len(examples_models_['pythia-12b'])
# Out:
# 92106

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(6.5, 5.5))

# color_palette = sns.color_palette('husl', len(examples_models))
# color_palette = sns.color_palette('Set2', len(examples_models_))
color_palette = plt.get_cmap('jet', len(examples_models_))
color_palette = [color_palette(i) for i in range(len(examples_models_))]

models = list(examples_models_.keys())

model_colormap = plt.cm.get_cmap('coolwarm', len(models))
# model_color_mapping = {model: model_colormap(1 - i / len(models)) for i, model in enumerate(models)}
model_color_mapping = {model: model_colormap(i) for i, model in enumerate(models)}
model_color_mapping['pythia-410m'] = (0.865395197, 0.86541021, 0.865395561, 1.0)
color_palette = [model_color_mapping[model] for model in models]

y_limits = None # [0,1.025]
is_log = False
plot_var = 'value'
savefile = os.path.join(FIGS_PTH, f"avg_em_by_log_interval_all_log{is_log}_{plot_var}_aligned{ALIGN_THRESH}.pdf")
for i, (model_name, data) in enumerate(examples_models_.items()):
    data = an.create_bins(data, plot_var, 0, 10000, 5, is_log)
    # data = ptqa.get_random_samples_by_interval(data, 85)
    ax = ptqa.plot_variable_by_interval(data, log_axis=is_log,
                                 x_column='interval', y_column='em',
                                 save_pth=savefile, ax=ax, 
                                 color=color_palette[i], label=model_name,
                                #  title=f'Performance vs. Ngrams for Different Models, {TASKS}, N={N_GRAMS}',
                                 plot_std=False, ylimits=y_limits)
    ax.legend(loc='upper left', ncol=1,
              fontsize=10)
# Out:
# /tmp/ipykernel_3432810/2080646415.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   model_colormap = plt.cm.get_cmap('coolwarm', len(models))
# interval
# [0.0000, 2000.0000)        89865
# [2000.0000, 4000.0000)     813
# [10000, ∞)                 739
# [4000.0000, 6000.0000)     349
# [6000.0000, 8000.0000)     196
# [8000.0000, 10000.0000)    144
# Name: count, dtype: int64
# avg_df =                          interval_start     avg_y
# interval
# [0.0000, 2000.0000)      0.0             0.354621
# [2000.0000, 4000.0000)   2000.0          0.405904
# [4000.0000, 6000.0000)   4000.0          0.481375
# [6000.0000, 8000.0000)   6000.0          0.479592
# [8000.0000, 10000.0000)  8000.0          0.506944
# [10000, ∞)               10000.0         0.500677
# avg_y: interval
# [0.0000, 2000.0000)        0.354621
# [2000.0000, 4000.0000)     0.405904
# [4000.0000, 6000.0000)     0.481375
# [6000.0000, 8000.0000)     0.479592
# [8000.0000, 10000.0000)    0.506944
# [10000, ∞)                 0.500677
# Name: avg_y, dtype: float64
# Saved figure in ./figures/trivia_qa/avg_em_by_log_interval_all_logFalse_value_aligned0.8.pdf
# interval
# [0.0000, 2000.0000)        89865
# [2000.0000, 4000.0000)     813
# [10000, ∞)                 739
# [4000.0000, 6000.0000)     349
# [6000.0000, 8000.0000)     196
# [8000.0000, 10000.0000)    144
# Name: count, dtype: int64
# avg_df =                          interval_start     avg_y
# interval
# [0.0000, 2000.0000)      0.0             0.302443
# [2000.0000, 4000.0000)   2000.0          0.341943
# [4000.0000, 6000.0000)   4000.0          0.404011
# [6000.0000, 8000.0000)   6000.0          0.433673
# [8000.0000, 10000.0000)  8000.0          0.458333
# [10000, ∞)               10000.0         0.437077
# avg_y: interval
# [0.0000, 2000.0000)        0.302443
# [2000.0000, 4000.0000)     0.341943
# [4000.0000, 6000.0000)     0.404011
# [6000.0000, 8000.0000)     0.433673
# [8000.0000, 10000.0000)    0.458333
# [10000, ∞)                 0.437077
# Name: avg_y, dtype: float64
# Saved figure in ./figures/trivia_qa/avg_em_by_log_interval_all_logFalse_value_aligned0.8.pdf
# interval
# [0.0000, 2000.0000)        89865
# [2000.0000, 4000.0000)     813
# [10000, ∞)                 739
# [4000.0000, 6000.0000)     349
# [6000.0000, 8000.0000)     196
# [8000.0000, 10000.0000)    144
# Name: count, dtype: int64
# avg_df =                          interval_start     avg_y
# interval
# [0.0000, 2000.0000)      0.0             0.224860
# [2000.0000, 4000.0000)   2000.0          0.295203
# [4000.0000, 6000.0000)   4000.0          0.332378
# [6000.0000, 8000.0000)   6000.0          0.321429
# [8000.0000, 10000.0000)  8000.0          0.354167
# [10000, ∞)               10000.0         0.365359
# avg_y: interval
# [0.0000, 2000.0000)        0.224860
# [2000.0000, 4000.0000)     0.295203
# [4000.0000, 6000.0000)     0.332378
# [6000.0000, 8000.0000)     0.321429
# [8000.0000, 10000.0000)    0.354167
# [10000, ∞)                 0.365359
# Name: avg_y, dtype: float64
# Saved figure in ./figures/trivia_qa/avg_em_by_log_interval_all_logFalse_value_aligned0.8.pdf
# interval
# [0.0000, 2000.0000)        89865
# [2000.0000, 4000.0000)     813
# [10000, ∞)                 739
# [4000.0000, 6000.0000)     349
# [6000.0000, 8000.0000)     196
# [8000.0000, 10000.0000)    144
# Name: count, dtype: int64
# avg_df =                          interval_start     avg_y
# interval
# [0.0000, 2000.0000)      0.0             0.145496
# [2000.0000, 4000.0000)   2000.0          0.182042
# [4000.0000, 6000.0000)   4000.0          0.200573
# [6000.0000, 8000.0000)   6000.0          0.168367
# [8000.0000, 10000.0000)  8000.0          0.236111
# [10000, ∞)               10000.0         0.235453
# avg_y: interval
# [0.0000, 2000.0000)        0.145496
# [2000.0000, 4000.0000)     0.182042
# [4000.0000, 6000.0000)     0.200573
# [6000.0000, 8000.0000)     0.168367
# [8000.0000, 10000.0000)    0.236111
# [10000, ∞)                 0.235453
# Name: avg_y, dtype: float64
# Saved figure in ./figures/trivia_qa/avg_em_by_log_interval_all_logFalse_value_aligned0.8.pdf
# interval
# [0.0000, 2000.0000)        89865
# [2000.0000, 4000.0000)     813
# [10000, ∞)                 739
# [4000.0000, 6000.0000)     349
# [6000.0000, 8000.0000)     196
# [8000.0000, 10000.0000)    144
# Name: count, dtype: int64
# avg_df =                          interval_start     avg_y
# interval
# [0.0000, 2000.0000)      0.0             0.067746
# [2000.0000, 4000.0000)   2000.0          0.088561
# [4000.0000, 6000.0000)   4000.0          0.080229
# [6000.0000, 8000.0000)   6000.0          0.081633
# [8000.0000, 10000.0000)  8000.0          0.083333
# [10000, ∞)               10000.0         0.087957
# avg_y: interval
# [0.0000, 2000.0000)        0.067746
# [2000.0000, 4000.0000)     0.088561
# [4000.0000, 6000.0000)     0.080229
# [6000.0000, 8000.0000)     0.081633
# [8000.0000, 10000.0000)    0.083333
# [10000, ∞)                 0.087957
# Name: avg_y, dtype: float64
# Saved figure in ./figures/trivia_qa/avg_em_by_log_interval_all_logFalse_value_aligned0.8.pdf
# interval
# [0.0000, 2000.0000)        89865
# [2000.0000, 4000.0000)     813
# [10000, ∞)                 739
# [4000.0000, 6000.0000)     349
# [6000.0000, 8000.0000)     196
# [8000.0000, 10000.0000)    144
# Name: count, dtype: int64
# avg_df =                          interval_start     avg_y
# interval
# [0.0000, 2000.0000)      0.0             0.012296
# [2000.0000, 4000.0000)   2000.0          0.012300
# [4000.0000, 6000.0000)   4000.0          0.017192
# [6000.0000, 8000.0000)   6000.0          0.010204
# [8000.0000, 10000.0000)  8000.0          0.013889
# [10000, ∞)               10000.0         0.010825
# avg_y: interval
# [0.0000, 2000.0000)        0.012296
# [2000.0000, 4000.0000)     0.012300
# [4000.0000, 6000.0000)     0.017192
# [6000.0000, 8000.0000)     0.010204
# [8000.0000, 10000.0000)    0.013889
# [10000, ∞)                 0.010825
# Name: avg_y, dtype: float64
# Saved figure in ./figures/trivia_qa/avg_em_by_log_interval_all_logFalse_value_aligned0.8.pdf
# interval
# [0.0000, 2000.0000)        89865
# [2000.0000, 4000.0000)     813
# [10000, ∞)                 739
# [4000.0000, 6000.0000)     349
# [6000.0000, 8000.0000)     196
# [8000.0000, 10000.0000)    144
# Name: count, dtype: int64
# avg_df =                          interval_start     avg_y
# interval
# [0.0000, 2000.0000)      0.0             0.002081
# [2000.0000, 4000.0000)   2000.0          0.000000
# [4000.0000, 6000.0000)   4000.0          0.000000
# [6000.0000, 8000.0000)   6000.0          0.000000
# [8000.0000, 10000.0000)  8000.0          0.000000
# [10000, ∞)               10000.0         0.000000
# avg_y: interval
# [0.0000, 2000.0000)        0.002081
# [2000.0000, 4000.0000)     0.000000
# [4000.0000, 6000.0000)     0.000000
# [6000.0000, 8000.0000)     0.000000
# [8000.0000, 10000.0000)    0.000000
# [10000, ∞)                 0.000000
# Name: avg_y, dtype: float64
# Saved figure in ./figures/trivia_qa/avg_em_by_log_interval_all_logFalse_value_aligned0.8.pdf
# interval
# [0.0000, 2000.0000)        89865
# [2000.0000, 4000.0000)     813
# [10000, ∞)                 739
# [4000.0000, 6000.0000)     349
# [6000.0000, 8000.0000)     196
# [8000.0000, 10000.0000)    144
# Name: count, dtype: int64
# avg_df =                          interval_start     avg_y
# interval
# [0.0000, 2000.0000)      0.0             0.001614
# [2000.0000, 4000.0000)   2000.0          0.001230
# [4000.0000, 6000.0000)   4000.0          0.002865
# [6000.0000, 8000.0000)   6000.0          0.000000
# [8000.0000, 10000.0000)  8000.0          0.000000
# [10000, ∞)               10000.0         0.000000
# avg_y: interval
# [0.0000, 2000.0000)        0.001614
# [2000.0000, 4000.0000)     0.001230
# [4000.0000, 6000.0000)     0.002865
# [6000.0000, 8000.0000)     0.000000
# [8000.0000, 10000.0000)    0.000000
# [10000, ∞)                 0.000000
# Name: avg_y, dtype: float64
# Saved figure in ./figures/trivia_qa/avg_em_by_log_interval_all_logFalse_value_aligned0.8.pdf
# interval
# [0.0000, 2000.0000)        89865
# [2000.0000, 4000.0000)     813
# [10000, ∞)                 739
# [4000.0000, 6000.0000)     349
# [6000.0000, 8000.0000)     196
# [8000.0000, 10000.0000)    144
# Name: count, dtype: int64
# avg_df =                          interval_start     avg_y
# interval
# [0.0000, 2000.0000)      0.0             0.006866
# [2000.0000, 4000.0000)   2000.0          0.007380
# [4000.0000, 6000.0000)   4000.0          0.000000
# [6000.0000, 8000.0000)   6000.0          0.005102
# [8000.0000, 10000.0000)  8000.0          0.000000
# [10000, ∞)               10000.0         0.008119
# avg_y: interval
# [0.0000, 2000.0000)        0.006866
# [2000.0000, 4000.0000)     0.007380
# [4000.0000, 6000.0000)     0.000000
# [6000.0000, 8000.0000)     0.005102
# [8000.0000, 10000.0000)    0.000000
# [10000, ∞)                 0.008119
# Name: avg_y, dtype: float64
# Saved figure in ./figures/trivia_qa/avg_em_by_log_interval_all_logFalse_value_aligned0.8.pdf

# %%
examples_model = examples_models['pythia-12b']
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 500)
# Corrected code
pd.set_option('display.max_colwidth', 1)
examples_model[VIEW_COLS].head(5)
# Out:
#                                  Q              A  \
# 25  in the middle of the            Pear
# 22  at the beginning of the         45
# 38  is the square root of           99
# 37  is the square root of           12
# 75  President of the United States  Ronald Reagan
#
#                                                                             question  \
# 25  Which fruit can go in the middle of the word aped to make a new word?
# 22  How many American states were there at the beginning of the twentieth century?
# 38  What whole two-digit number is the square root of 9801?
# 37  What is the square root of 144?
# 75  June 5, 2004 saw the death of what man, the 40th President of the United States?
#
#       value  align_score  em  \
# 25  1837603  78.528419    0
# 22  1815794  76.193657    0
# 38  1022052  83.908638    0
# 37  1022052  84.854713    1
# 75  615844   82.827179    1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  answer
# 25  {'aliases': ['Pear (fruit)', 'Pear tree', 'Pear', 'Culture of pear', '🍐', 'Pear juice', 'Pearwood', 'Pyrus'], 'normalized_aliases': ['🍐', 'culture of pear', 'pyrus', 'pearwood', 'pear tree', 'pear juice', 'pear', 'pear fruit'], 'matched_wiki_entity_name': '', 'normalized_matched_wiki_entity_name': '', 'normalized_value': 'pear', 'type': 'WikipediaEntity', 'value': 'Pear'}
# 22  {'aliases': ['45', 'forty-five'], 'normalized_aliases': ['45', 'forty five'], 'matched_wiki_entity_name': '', 'normalized_matched_wiki_entity_name': '', 'normalized_value': '45', 'type': 'Numerical', 'value': '45'}
# 38  {'aliases': ['99', 'ninety-nine'], 'normalized_aliases': ['ninety nine', '99'], 'matched_wiki_entity_name': '', 'normalized_matched_wiki_entity_name': '', 'normalized_value': '99', 'type': 'Numerical', 'value': '99'}
# 37  {'aliases': ['twelve', '12'], 'normalized_aliases': ['twelve', '12'], 'matched_wiki_entity_name': '', 'normalized_matched_wiki_entity_name': '', 'normalized_value': '12', 'type': 'Numerical', 'value': '12'}
# 75  {'aliases': ['President Regan', 'Ronald Reagan's Alzheimer's letter', 'Ronald W Reagan', '40th President of the United States', 'Reagan', 'Reaganian', 'Ronald Reagon', 'Reagen', 'Ronnie Reagan', 'Public image of Ronald Reagan', 'Ronald Reagan presidential campaign, 1976', 'Ronald Reagan', 'Reagan, Ronald', 'Reagan, Ronald Wilson', 'President Reagan', 'Reagan (president)', 'Health of Ronald Reagan', 'President Ronald Reagan', 'Ronald Reagan Centennial Commission Act', 'Ronald reagan', 'Reaganesque', 'Reaganite', 'Ronald Raegen', 'Ronald regean', 'Ronald Wilson Reagan', 'Ronald Regan', 'Ronald Reagan Centennial Commission', 'Dutch Reagan', 'Ronaldus Magnus', 'Ronald Reagen', 'Cultural and political image of Ronald Reagan', 'Ronal Reagan', 'Reagan Ronald', 'Ronald Raegan', 'Ronald W. Reagan'], 'normalized_aliases': ['reagan ronald wilson', 'reaganesque', 'ronald raegan', 'ronald reagon', 'ronald reagan s alzheimer s letter', 'ronald reagan', 'ronald w reagan', 'president reagan', 'reagan', 'reaganite', 'ronnie reagan', 'public image of ronald reagan', 'ronald reagen', 'reagan president', 'ronald regean', 'ronald regan', 'ronald wilson reagan', 'dutch reagan', '40th president of united states', 'reagen', 'ronald reagan presidential campaign 1976', 'ronaldus magnus', 'president regan', 'president ronald reagan', 'ronal reagan', 'ronald reagan centennial commission', 'health of ronald reagan', 'ronald raegen', 'cultural and political image of ronald reagan', 'reaganian', 'ronald reagan centennial commission act', 'reagan ronald'], 'matched_wiki_entity_name': '', 'normalized_matched_wiki_entity_name': '', 'normalized_value': 'ronald reagan', 'type': 'WikipediaEntity', 'value': 'Ronald Reagan'}

# %%
question = "What is the medical term for high blood pressure?"
df_q = examples_model[examples_model['question'] == question]
df_q['Q']
# Out:
# 18125    is the medical term for
# 18123    term for high blood pressure
# 18124    medical term for high blood
# 18122    the medical term for high
# 18121    What is the medical term
# Name: Q, dtype: object

# %%
# from src.utils import normalize_string

# # Apply the function to each row of the DataFrame
# # examples_model[['q_coverage', 'a_coverage']] = examples_model.apply(calculate_qa_coverage, axis=1)

# coverage_df = an.calculate_qa_coverage(examples_model)

# coverage_df['q_coverage'].unique()

# coverage_df[coverage_df['q_coverage'] < 0]

# %%
is_log = False
plot_var = 'q_coverage'
x_label = 'Question Coverage (p)'

examples_model_cov_int = an.create_bins(coverage_df, plot_var, 
                                        -0.1, 1.0, 5, 
                                        is_log=is_log)

ptqa.plot_variable_by_interval(examples_model_cov_int, log_axis=is_log,
                                x_column='interval', y_column='em',
                                save_pth=savefile, 
                                label='pythia-12b',
                                title=f'Performance vs. {plot_var} for Different Models N={N_GRAMS}',
                                x_label=x_label, 
                                plot_std=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       2 plot_var = 'q_coverage'
#       3 x_label = 'Question Coverage (p)'
# ----> 5 examples_model_cov_int = an.create_bins(coverage_df, plot_var,
#       6                                         -0.1, 1.0, 5,
#       7                                         is_log=is_log)
#       9 ptqa.plot_variable_by_interval(examples_model_cov_int, log_axis=is_log,
#      10                                 x_column='interval', y_column='em',
#      11                                 save_pth=savefile,
#    (...)
#      14                                 x_label=x_label,
#      15                                 plot_std=True)
#
# NameError: name 'coverage_df' is not defined
